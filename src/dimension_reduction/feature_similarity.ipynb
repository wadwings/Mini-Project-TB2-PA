# %%
from Bio import pairwise2
from Bio.Seq import Seq
S =#%%
from Bio import pairwise2
from Bio.Seq import Seq
S = '''
from Bio import SubsMat

# Define the weights for the alignment
weights = MatrixInfo.blosum62

# Compute the pairwise alignments and scores
for i in range(len(sequences)):
    for j in range(i+1, len(sequences)):
        seq1 = sequences[i]
        seq2 = sequences[j]
        alignment = pairwise2.align.globalds(seq1, seq2, weights, -10, -0.5)
        score = alignment[0][2]
        print(f"Alignment score between {seq1} and {seq2}: {score}")

# %%
'''

# Example TRAV gene segments
seq1 = "26-1"
seq2 = "26-2"

# Convert the sequences to Biopython Seq objects
seq1 = Seq(seq1)
seq2 = Seq(seq2)

# Align the sequences using the Needleman-Wunsch algorithm
alignments = pairwise2.align.globalxx(seq1, seq2)

# Print the alignment with the highest score
print(pairwise2.format_alignment(*alignments[0]))

# %%
from Bio import pairwise2

# Example TRAV gene segments
sequences = ["TRAV26-1*01", "TRAV20*01", "TRAV38-2/DV8*01", "TRAV26-1*01", "TRAV20*01", "TRAV26-1*01", "TRAV20*01", "TRAV26-1*01", "TRAV20*01", "TRAV38-1*01", "TRAV12-2*01", "TRAV12-2*01", "TRAV12-2*01", "TRAV12-2*01", "TRAV12-2*01", "TRAV12-2*01", "TRAV12-2*01", "TRAV12-2*01", "TRAV12-2*01", "TRAV12-2*01", "TRAV12-2*01", "TRAV12-2*01", "TRAV12-2*01", "TRAV12-2*01", "TRAV12-2*01", "TRAV3*01", "TRAV12-1*01", "TRAV27*01", "TRAV1-2*01", "TRAV35*01", "TRAV13-2*01", "TRAV12-2*01", "TRAV12-2*01", "TRAV12-2*01", "TRAV12-2*01", "TRAV12-2*01", "TRAV12-2*01", "TRAV12-2*01", "TRAV12-2*01", "TRAV3*01", "TRAV12-2*01", "TRAV12-2*01", "TRAV12-2*01", "TRAV12-2*01", "TRAV12-2*01", "TRAV12-2*01", "TRAV12-2*01", "TRAV12-3*01", "TRAV12-3*01", "TRAV12-3*01", "TRAV13-1*01", "TRAV13-1*01", "TRAV13-1*01", "TRAV13-1*01", "TRAV13-1*01", "TRAV13-1*01", "TRAV8-4*01", "TRAV8-1*01", "TRAV3*01", "TRAV14/DV4*01", "TRAV3*01", "TRAV26-1*01"]


# Compute pairwise alignment scores using Needleman-Wunsch
align_scores = {}
for i, seq1 in enumerate(sequences):
    for j, seq2 in enumerate(sequences):
        if j > i:
            align_score = pairwise2.align.globalxx(seq1, seq2, score_only=True)
            align_scores[(i, j)] = align_score
            align_scores[(j, i)] = align_score

# Print the alignment scores
for i, seq1 in enumerate(sequences):
    for j, seq2 in enumerate(sequences):
        if j > i:
            print(f"Alignment score between {seq1} and {seq2}: {align_scores[(i, j)]}")

# %%
from Bio import pairwise2

def get_similarity_score(seq1, seq2):
    alignments = pairwise2.align.globalxx(seq1, seq2)
    alignment_scores = [a[2] for a in alignments]
    return max(alignment_scores, default=0)

sequences = ["26-1*01", "TRAV20*01", "TRAV38-2/DV8*01", "TRAV26-1*01", "TRAV20*01", "TRAV26-1*01", "TRAV20*01", "TRAV26-1*01", "TRAV20*01", "TRAV38-1*01", "TRAV12-2*01", "TRAV12-2*01", "TRAV12-2*01", "TRAV12-2*01", "TRAV12-2*01", "TRAV12-2*01", "TRAV12-2*01", "TRAV12-2*01", "TRAV12-2*01", "TRAV12-2*01", "TRAV12-2*01", "TRAV12-2*01", "TRAV12-2*01", "TRAV12-2*01", "TRAV12-2*01", "TRAV3*01", "TRAV12-1*01", "TRAV27*01", "TRAV1-2*01", "TRAV35*01", "TRAV13-2*01", "TRAV12-2*01", "TRAV12-2*01", "TRAV12-2*01", "TRAV12-2*01", "TRAV12-2*01", "TRAV12-2*01", "TRAV12-2*01", "TRAV12-2*01", "TRAV3*01", "TRAV12-2*01", "TRAV12-2*01", "TRAV12-2*01", "TRAV12-2*01", "TRAV12-2*01", "TRAV12-2*01", "TRAV12-2*01", "TRAV12-3*01", "TRAV12-3*01", "TRAV12-3*01", "TRAV13-1*01", "TRAV13-1*01", "TRAV13-1*01", "TRAV13-1*01", "TRAV13-1*01", "TRAV13-1*01", "TRAV8-4*01", "TRAV8-1*01", "TRAV3*01", "TRAV14/DV4*01", "TRAV3*01", "TRAV26-1*01"]

scores = {}
for seq in sequences:
    score = sum(get_similarity_score(seq, other_seq) for other_seq in sequences)
    scores[seq] = score

print(scores)

# %%
'''
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import pairwise_distances
import scipy.spatial.distance as dist

# Create a count vectorizer to convert the strings into binary term frequencies
vectorizer = CountVectorizer(binary=True)
X = vectorizer.fit_transform(sequences)

dense_matrix = X.toarray()

# Compute pairwise distances between rows
distances = dist.pdist(dense_matrix, metric='cosine')
square_distances = dist.squareform(distances)

# Calculate the score for each string as the average similarity with the other strings
scores = []
for i in range(len(sequences)):
    score = sum(square_distances[i]) / (len(sequences) - 1)
    scores.append(score)

# Print the scores for each string
for i in range(len(sequences)):
    print(f"{sequences[i]}: {scores[i]}")
'''

# %%
from src.preprocess.setup import config
from src.preprocess.feature_filter import load_data
from src.preprocess.label import generate_label
import src.preprocess.feature_filter

config.setConfig(config.speciesType.human, config.chainType.alpha)
data = load_data()

# %%
sequences_1 = data['v_a_gene']
print(sequences_1)

# %%
from Bio.Align.Applications import MuscleCommandline
from io import StringIO
from Bio import AlignIO

# Extract V column from sequences list
sequences_V = [s.split('\t')[0] for s in sequences]

# Write sequences to a temporary file
temp_seq_file = 'sequences.fasta'
with open(temp_seq_file, 'w') as f:
    for i, seq in enumerate(sequences_V):
        f.write('>seq{}\n{}\n'.format(i, seq))

# Run MUSCLE alignment
muscle_exe = '/Users/liuqianyi/Documents/muscle/muscle.macos_intel64'
muscle_cline = MuscleCommandline(muscle_exe, input=temp_seq_file)
stdout, stderr = muscle_cline()
align = AlignIO.read(StringIO(stdout), 'fasta')

# Print similarity scores
for i, record1 in enumerate(align):
    for j, record2 in enumerate(align):
        score = align[:, i].similarity(align[:, j])
        print('{} vs {}: {}'.format(record1.id, record2.id, score))

# %%
# Example TRAV gene segments
seq1 = "BYJEATCG"
seq2 = "ATCG"

# Convert the sequences to Biopython Seq objects
seq1 = Seq(seq1)
seq2 = Seq(seq2)


# Align the sequences using the Needleman-Wunsch algorithm
alignments = pairwise2.align.localms(seq1, seq2, 1, -1, -0.5, -0.1, one_alignment_only=True)

# Print the alignment with the highest score
print(pairwise2.format_alignment(*alignments[0]))
# Out:
# 5 ATCG
#   ||||
# 1 ATCG
#   Score=4

# %%
from Bio import pairwise2

# Example TRAV gene segments
sequences = ['12-2', '12-1', '12-3', '13-1', '8-4', '8-1', '14/DV4', '4', '5', '19', '9-2', '22', '25', '10', '39', '41', '2', '9-1', '1-1', '8-6', '26-2', '24', '8-3', '17', '29/DV5', '16', '30', '6', '23/DV6', '36/DV7', '8-2', '18', '34', '40', '7', '14/DV4*02', '8-6*02']


# Compute pairwise alignment scores using Needleman-Wunsch
align_scores = {}
for i, seq1 in enumerate(sequences):
    for j, seq2 in enumerate(sequences):
        if j > i:
            align_score = pairwise2.align.globalxx(seq1, seq2, score_only=True)
            align_scores[(i, j)] = align_score
            align_scores[(j, i)] = align_score

# Print the alignment scores
for i, seq1 in enumerate(sequences):
    for j, seq2 in enumerate(sequences):
        if j > i:
            print(f"Alignment score between {seq1} and {seq2}: {align_scores[(i, j)]}")
# Out:
# Alignment score between 12-2 and 12-1: 3.0
# Alignment score between 12-2 and 12-3: 3.0
# Alignment score between 12-2 and 13-1: 2.0
# Alignment score between 12-2 and 8-4: 1.0
# Alignment score between 12-2 and 8-1: 1.0
# Alignment score between 12-2 and 14/DV4: 1.0
# Alignment score between 12-2 and 4: 0.0
# Alignment score between 12-2 and 5: 0.0
# Alignment score between 12-2 and 19: 1.0
# Alignment score between 12-2 and 9-2: 2.0
# Alignment score between 12-2 and 22: 2.0
# Alignment score between 12-2 and 25: 1.0
# Alignment score between 12-2 and 10: 1.0
# Alignment score between 12-2 and 39: 0.0
# Alignment score between 12-2 and 41: 1.0
# Alignment score between 12-2 and 2: 1.0
# Alignment score between 12-2 and 9-1: 1.0
# Alignment score between 12-2 and 1-1: 2.0
# Alignment score between 12-2 and 8-6: 1.0
# Alignment score between 12-2 and 26-2: 3.0
# Alignment score between 12-2 and 24: 1.0
# Alignment score between 12-2 and 8-3: 1.0
# ...

# %%
from Bio import pairwise2

def get_similarity_score(seq1, seq2):
    alignments = pairwise2.align.globalxx(seq1, seq2)
    alignment_scores = [a[2] for a in alignments]
    return max(alignment_scores, default=0)

sequences = ['12-2', '12-1', '12-3', '13-1', '8-4', '8-1', '14/DV4', '4', '5', '19', '9-2', '22', '25', '10', '39', '41', '2', '9-1', '1-1', '8-6', '26-2', '24', '8-3', '17', '29/DV5', '16', '30', '6', '23/DV6', '36/DV7', '8-2', '18', '34', '40', '7', '14/DV4*02', '8-6*02']

scores = {}
for seq in sequences:
    score = sum(get_similarity_score(seq, other_seq) for other_seq in sequences)
    scores[seq] = score

print(scores)
# Out:
# {'12-2': 44.0, '12-1': 43.0, '12-3': 45.0, '13-1': 38.0, '8-4': 29.0, '8-1': 33.0, '14/DV4': 39.0, '4': 8.0, '5': 3.0, '19': 19.0, '9-2': 30.0, '22': 17.0, '25': 17.0, '10': 20.0, '39': 13.0, '41': 21.0, '2': 14.0, '9-1': 31.0, '1-1': 32.0, '8-6': 27.0, '26-2': 36.0, '24': 21.0, '8-3': 28.0, '17': 18.0, '29/DV5': 35.0, '16': 22.0, '30': 13.0, '6': 7.0, '23/DV6': 41.0, '36/DV7': 32.0, '8-2': 33.0, '18': 21.0, '34': 16.0, '40': 13.0, '7': 3.0, '14/DV4*02': 57.0, '8-6*02': 45.0}

# %%
'''
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import pairwise_distances
import scipy.spatial.distance as dist

# Create a count vectorizer to convert the strings into binary term frequencies
vectorizer = CountVectorizer(binary=True)
X = vectorizer.fit_transform(sequences)

dense_matrix = X.toarray()

# Compute pairwise distances between rows
distances = dist.pdist(dense_matrix, metric='cosine')
square_distances = dist.squareform(distances)

# Calculate the score for each string as the average similarity with the other strings
scores = []
for i in range(len(sequences)):
    score = sum(square_distances[i]) / (len(sequences) - 1)
    scores.append(score)

# Print the scores for each string
for i in range(len(sequences)):
    print(f"{sequences[i]}: {scores[i]}")
'''
# Out:
# TRAV26-1*01: 0.47022136752577504
# TRAV20*01: 0.47841808883725045
# TRAV38-2/DV8*01: 0.5862872286618203
# TRAV26-1*01: 0.47022136752577504
# TRAV20*01: 0.47841808883725045
# TRAV26-1*01: 0.47022136752577504
# TRAV20*01: 0.47841808883725045
# TRAV26-1*01: 0.47022136752577504
# TRAV20*01: 0.47841808883725045
# TRAV38-1*01: 0.4963156578460396
# TRAV12-2*01: 0.23251644949298814
# TRAV12-2*01: 0.23251644949298814
# TRAV12-2*01: 0.23251644949298814
# TRAV12-2*01: 0.23251644949298814
# TRAV12-2*01: 0.23251644949298814
# TRAV12-2*01: 0.23251644949298814
# TRAV12-2*01: 0.23251644949298814
# TRAV12-2*01: 0.23251644949298814
# TRAV12-2*01: 0.23251644949298814
# TRAV12-2*01: 0.23251644949298814
# TRAV12-2*01: 0.23251644949298814
# TRAV12-2*01: 0.23251644949298814
# TRAV12-2*01: 0.23251644949298814
# TRAV12-2*01: 0.23251644949298814
# TRAV12-2*01: 0.23251644949298814
# TRAV3*01: 0.47841808883725045
# TRAV12-1*01: 0.23251644949298814
# TRAV27*01: 0.5030082527716767
# ...

# %%
from src.preprocess.setup import config
from src.preprocess.feature_filter import load_data
from src.preprocess.label import generate_label
import src.preprocess.feature_filter

config.setConfig(config.speciesType.human, config.chainType.alpha)
data = load_data()
print(data)
# Out:
# fetching data stage
#               cdr3_a_aa         v_a_gene   j_a_gene             cdr3_b_aa  \
# 0         CIVRAPGRADMRF      TRAV26-1*01  TRAJ43*01  CASSYLPGQGDHYSNQPQHF
# 2        CAVPSGAGSYQLTF        TRAV20*01  TRAJ28*01   CASSFEPGQGFYSNQPQHF
# 4         CAYRPPGTYKYIF  TRAV38-2/DV8*01  TRAJ40*01        CASSALASLNEQFF
# 5         CIVRAPGRADMRF      TRAV26-1*01  TRAJ43*01  CASSYLPGQGDHYSNQPQHF
# 7        CAVPSGAGSYQLTF        TRAV20*01  TRAJ28*01   CASSFEPGQGFYSNQPQHF
# ...                 ...              ...        ...                   ...
# 59806      CAVYNQGGKLIF       TRAV8-1*01  TRAJ23*01      CASSALVAFSTDTQYF
# 59807    CAVRALYNFNKFYF         TRAV3*01  TRAJ21*01       CASSSLAGEVNEQFF
# 59808     CAVESYNTDKLIF        TRAV41*01  TRAJ34*01   CASSSYTQRGLDYTGELFF
# 59810    CLVGENSGGFKTIF         TRAV4*01   TRAJ9*01                   NaN
# 59811  CAMREGQGNAGNMLTF    TRAV14/DV4*01  TRAJ39*01     CASSQDYWGGGADTQYF
#
# ...

# %%
import numpy as np
x = data['v_a_gene'].unique()
print(x)

j_a_gene = data['j_a_gene'].unique()
print(j_a_gene)



output_list = [s.replace('TRAV', '').replace('*01', '') for s in x]

print(output_list)

'''
scores = {}
for seq in sequences:
    score = sum(get_similarity_score(seq, other_seq) for other_seq in sequences)
    scores[seq] = score

print(scores)

'''
# Out:
# ['TRAV26-1*01' 'TRAV20*01' 'TRAV38-2/DV8*01' 'TRAV38-1*01' 'TRAV12-2*01'
#  'TRAV3*01' 'TRAV12-1*01' 'TRAV27*01' 'TRAV1-2*01' 'TRAV35*01'
#  'TRAV13-2*01' 'TRAV21*01' 'TRAV12-3*01' 'TRAV13-1*01' 'TRAV8-4*01'
#  'TRAV8-1*01' 'TRAV14/DV4*01' 'TRAV4*01' 'TRAV5*01' 'TRAV19*01'
#  'TRAV9-2*01' 'TRAV22*01' 'TRAV25*01' 'TRAV10*01' 'TRAV39*01' 'TRAV41*01'
#  'TRAV2*01' 'TRAV9-1*01' 'TRAV1-1*01' 'TRAV8-6*01' 'TRAV26-2*01'
#  'TRAV24*01' 'TRAV8-3*01' 'TRAV17*01' 'TRAV29/DV5*01' 'TRAV16*01'
#  'TRAV30*01' 'TRAV6*01' 'TRAV23/DV6*01' 'TRAV36/DV7*01' 'TRAV8-2*01'
#  'TRAV18*01' 'TRAV34*01' 'TRAV40*01' 'TRAV7*01' 'TRAV14/DV4*02'
#  'TRAV8-6*02']
# ['TRAJ43*01' 'TRAJ28*01' 'TRAJ40*01' 'TRAJ48*01' 'TRAJ42*01' 'TRAJ45*01'
#  'TRAJ23*01' 'TRAJ31*01' 'TRAJ53*01' 'TRAJ39*01' 'TRAJ7*01' 'TRAJ3*01'
#  'TRAJ20*01' 'TRAJ9*01' 'TRAJ33*01' 'TRAJ22*01' 'TRAJ37*01' 'TRAJ47*01'
#  'TRAJ34*01' 'TRAJ8*01' 'TRAJ57*01' 'TRAJ21*01' 'TRAJ54*01' 'TRAJ49*01'
# ...

# %%
'''
from Bio.Align.Applications import MuscleCommandline
from io import StringIO
from Bio import AlignIO

# Extract V column from sequences list
sequences_V = [s.split('\t')[0] for s in sequences]

# Write sequences to a temporary file
temp_seq_file = 'sequences.fasta'
with open(temp_seq_file, 'w') as f:
    for i, seq in enumerate(sequences_V):
        f.write('>seq{}\n{}\n'.format(i, seq))

# Run MUSCLE alignment
muscle_exe = '/Users/liuqianyi/Documents/muscle/muscle.macos_intel64'
muscle_cline = MuscleCommandline(muscle_exe, input=temp_seq_file)
stdout, stderr = muscle_cline()
align = AlignIO.read(StringIO(stdout), 'fasta')

# Print similarity scores
for i, record1 in enumerate(align):
    for j, record2 in enumerate(align):
        score = align[:, i].similarity(align[:, j])
        print('{} vs {}: {}'.format(record1.id, record2.id, score))
'''

# %%
# Select the columns of interest
columns = ['26-1', '20', '38-2/DV8', '38-1', '12-2', '3', '12-1', '27', '1-2', '35', '13-2', '21', '12-3', '13-1', '8-4', '8-1', '14/DV4', '4', '5', '19', '9-2', '22', '25', '10', '39', '41', '2', '9-1', '1-1', '8-6', '26-2', '24', '8-3', '17', '29/DV5', '16', '30', '6', '23/DV6', '36/DV7', '8-2', '18', '34', '40', '7', '14/DV4*02', '8-6*02']
from fuzzywuzzy import fuzz

columns = ['12-2', '12-1', '12-3', '13-1', '8-4', '8-1', '14/DV4', '4', '5', '19', '9-2', '22', '25', '10', '39', '41', '2', '9-1', '1-1', '8-6', '26-2', '24', '8-3', '17', '29/DV5', '16', '30', '6', '23/DV6', '36/DV7', '8-2', '18', '34', '40', '7', '14/DV4*02', '8-6*02']

# Compute the similarity score for each pair of strings
similarity_scores = []
for i in range(len(columns)):
    for j in range(i+1, len(columns)):
        score = fuzz.token_sort_ratio(columns[i], columns[j])
        similarity_scores.append((columns[i], columns[j], score))

# Sort the scores in descending order
similarity_scores.sort(key=lambda x: x[2], reverse=True)

# Print the top 10 pairs of strings with the highest similarity scores
for i in range(10):
    print(similarity_scores[i])
# Out:
# ('12-1', '1-1', 86)
# ('13-1', '1-1', 86)
# ('8-1', '18', 80)
# ('14/DV4', '14/DV4*02', 80)
# ('19', '9-1', 80)
# ('12-2', '12-3', 75)
# ('12-2', '26-2', 75)
# ('12-1', '13-1', 75)
# ('12-3', '13-1', 75)
# ('12-2', '22', 67)
# /Users/liuqianyi/Mini-Project-TB2-PA/venv/lib/python3.11/site-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')
