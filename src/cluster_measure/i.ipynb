# %%
import sys
sys.path.append('../distance_compute')

# %%
from setup import config
config.setConfig(config.speciesType.human, config.chainType.alpha)
print(config.getColumns())
# Out:
# fetching data stage
#                 cdr3_a_aa       v_a_gene   j_a_gene  count
# 0          AQGLLTGGGNKLTF  TRAV29/DV5*01  TRAJ10*01      1
# 1          ASMFSGGGNEKFTF    TRAV12-2*01  TRAJ48*01      1
# 2          ASMYKGGGNEKFTF    TRAV26-2*01  TRAJ45*01      1
# 3          CAAAASGGSYIPTF     TRAV1-2*01   TRAJ6*01      1
# 4         CAAAATPGNTGKLIF    TRAV12-2*01  TRAJ37*01      1
# ...                   ...            ...        ...    ...
# 25364         WGDRKTRNSYF      TRAV27*01  TRAJ42*01      1
# 25365            WGGNKLVF       TRAV6*01  TRAJ47*01      1
# 25366           WGTGNQFYF      TRAV39*01  TRAJ49*01      1
# 25367  YFLSSGARVTGGGNKITF     TRAV9-2*01  TRAJ10*01      1
# 25368           YGSTDKLIF      TRAV39*01  TRAJ34*01      1
#
# [25369 rows x 4 columns]

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
import numpy as np
import random
from distance_compute import compute_single_distance


X = [random.random() for _ in range(200)]
np.array(X).reshape(-1,1)
Y = [1 for _ in range(200)]
X_train, X_test, Y_train, Y_test = train_test_split(X, Y)


clf = KNeighborsClassifier(metric=compute_single_distance)

clf.fit(X_train,)

clf.predict(X_test)
# Out:
# x: [0.45786163], y: [0.2176091]
# x: [0.45786163], y: [0.62789237]
# x: [0.45786163], y: [0.12414305]
# x: [0.45786163], y: [0.26372081]
# x: [0.45786163], y: [0.0301233]
# x: [0.45786163], y: [0.19100913]
# x: [0.45786163], y: [0.41372745]
# x: [0.45786163], y: [0.44901296]
# x: [0.45786163], y: [0.38036155]
# x: [0.45786163], y: [0.77852264]
# x: [0.45786163], y: [0.37436302]
# x: [0.45786163], y: [0.78133977]
# x: [0.45786163], y: [0.2461811]
# x: [0.45786163], y: [0.21729934]
# x: [0.45786163], y: [0.17527847]
# x: [0.45786163], y: [0.28297095]
# x: [0.45786163], y: [0.37619751]
# x: [0.45786163], y: [0.35781356]
# x: [0.45786163], y: [0.13222632]
# x: [0.45786163], y: [0.2987519]
# x: [0.45786163], y: [0.36007903]
# x: [0.45786163], y: [0.25958856]
# x: [0.45786163], y: [0.06695397]
# x: [0.45786163], y: [0.64616399]
# x: [0.45786163], y: [0.1938077]
# x: [0.45786163], y: [0.51162597]
# x: [0.45786163], y: [0.21640446]
# x: [0.45786163], y: [0.27630821]
# ...
